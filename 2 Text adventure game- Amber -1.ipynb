# %%
"""The Matrix

A game by Amber Wang for Data Science: Python.
(c) 2022

"""

#Welcome to users
input(prompt= 
      
      ''' 
                                                                                                               
        
        
        
████████╗██╗  ██╗███████╗    ███╗   ███╗ █████╗ ████████╗██████╗ ██╗██╗  ██╗
╚══██╔══╝██║  ██║██╔════╝    ████╗ ████║██╔══██╗╚══██╔══╝██╔══██╗██║╚██╗██╔╝
   ██║   ███████║█████╗      ██╔████╔██║███████║   ██║   ██████╔╝██║ ╚███╔╝ 
   ██║   ██╔══██║██╔══╝      ██║╚██╔╝██║██╔══██║   ██║   ██╔══██╗██║ ██╔██╗ 
   ██║   ██║  ██║███████╗    ██║ ╚═╝ ██║██║  ██║   ██║   ██║  ██║██║██╔╝ ██╗
   ╚═╝   ╚═╝  ╚═╝╚══════╝    ╚═╝     ╚═╝╚═╝  ╚═╝   ╚═╝   ╚═╝  ╚═╝╚═╝╚═╝  ╚═╝
                                                                            

                                                                      .         .                                                                                       

Welcome to The New Matrix text adventure game by Amber Wang! ❤️
Have you watched the movie - The Matrix?

Are you satisfied with the new Matrix 4- The Matrix Resurrections?
If yes, what would you like to rewrite The Matrix Resurrections?

There are 3 stages in this game which Leo must go through in order to bring Trinity back home:
   
        Stage1) Choose the right pill: Red pill or blue pill
        Stage2) Have a good mindset: 9-5 job or follow your passion 
        Stage3) Save Trinity: Climate change or money

Now, imagine you are the main character- Leo, let's start the game!!
 \n\n <Press enter to continue the game>
 
 
 ''')


#########################################################
#########Creating a choice for stage one #######
#########################################################

#Named stage1_choice using Define function
def stage1_choice():
    """Get the pill choice from the player.
    """
    print("Morpheus gives you red pill and blue pill,\n Red pill:  Willing to learn a potentially unsettling or life-changing truth.\n Blue pill: Remaining in contented ignorance. \n")
          
    command = True 
    
    while(command): #Adding a loop to execute the statement if command is true or false
        
        user_input = input(prompt = 'Please answer by writing "red" or "blue", then hit enter.\n') #Getting the user input

#adding a condition (.lower allows the user to use any case they'd like.)
        if user_input.lower() == 'blue':
            print('''
            
            
 
 .-----------------. .----------------.  .----------------. 
| .--------------. || .--------------. || .--------------. |
| | ____  _____  | || |     ____     | || |              | |
| ||_   \|_   _| | || |   .'    `.   | || |      _       | |
| |  |   \ | |   | || |  /  .--.  \  | || |     | |      | |
| |  | |\ \| |   | || |  | |    | |  | || |     | |      | |
| | _| |_\   |_  | || |  \  `--'  /  | || |     | |      | |
| ||_____|\____| | || |   `.____.'   | || |     |_|      | |
| |              | || |              | || |     (_)      | |
| '--------------' || '--------------' || '--------------' |
 '----------------'  '----------------'  '----------------' 


            
I can't believe that you choose go back to sleep!!!''')
            command = False
            lose()

#continuing the condition
        elif user_input.lower() == 'red':
            print('''
            
            
            
 .----------------.  .----------------.  .----------------. 
| .--------------. || .--------------. || .--------------. |
| |  ____  ____  | || |      __      | || |              | |
| | |_  _||_  _| | || |     /  \     | || |      _       | |
| |   \ \  / /   | || |    / /\ \    | || |     | |      | |
| |    \ \/ /    | || |   / ____ \   | || |     | |      | |
| |    _|  |_    | || | _/ /    \ \_ | || |     | |      | |
| |   |______|   | || ||____|  |____|| || |     |_|      | |
| |              | || |              | || |     (_)      | |
| '--------------' || '--------------' || '--------------' |
 '----------------'  '----------------'  '----------------' 

            
You are my Leo! We need more people like you!!!''')
            command = False
            stage2_mindset()
            
#ending the condition       
        else: command =True




        
#########################################################
################# Test your mindset!! ###################
#########################################################


#Named stage1_mindset using Define function
def stage2_mindset():
    """Get the lifestyle choice of the player.
    """
    print("The goal is to get to know you if you have an adventurous spirit. \n Do you choose 9-5 job or something else follow your heart?\n")   
    
    command = True
    
    while(command): #Adding a loop to execute the statement if command is true or false
        
        user_input = input(prompt = 'Please answer by writing "9-5 job" or "follow my heart", then hit enter.\n') #Getting the user input

#adding a condition (.lower allows the user to use any case they'd like.)
        if user_input.lower() == '9-5 job':
            print('''
            
            
            
 .-----------------. .----------------.  .----------------. 
| .--------------. || .--------------. || .--------------. |
| | ____  _____  | || |     ____     | || |              | |
| ||_   \|_   _| | || |   .'    `.   | || |      _       | |
| |  |   \ | |   | || |  /  .--.  \  | || |     | |      | |
| |  | |\ \| |   | || |  | |    | |  | || |     | |      | |
| | _| |_\   |_  | || |  \  `--'  /  | || |     | |      | |
| ||_____|\____| | || |   `.____.'   | || |     |_|      | |
| |              | || |              | || |     (_)      | |
| '--------------' || '--------------' || '--------------' |
 '----------------'  '----------------'  '----------------' 

            
Sorry, you can't save the world! You are not my Leo!''')
            command = False
            lose()
            
#continuing the condition statement           
        elif user_input.lower() == 'follow my heart':
            print('''
            
            
            
 .----------------.  .----------------.  .----------------. 
| .--------------. || .--------------. || .--------------. |
| |  ____  ____  | || |      __      | || |              | |
| | |_  _||_  _| | || |     /  \     | || |      _       | |
| |   \ \  / /   | || |    / /\ \    | || |     | |      | |
| |    \ \/ /    | || |   / ____ \   | || |     | |      | |
| |    _|  |_    | || | _/ /    \ \_ | || |     | |      | |
| |   |______|   | || ||____|  |____|| || |     |_|      | |
| |              | || |              | || |     (_)      | |
| '--------------' || '--------------' || '--------------' |
 '----------------'  '----------------'  '----------------' 

            
I like your attitude. The world needs you!''')
            command = False
            stage2point5_trinity()
            
        
#ending the condition statment                  
        else: command = True    
        
  
#########################################################
############### Before save Trinity... ################
#########################################################

#adding randon choice.
#Named stage2.5_trinity using Define function
#add random choices
def stage2point5_trinity():
    import random
    num_choices = 3
    winning_items = ["machine-gun","white rabbit"]
    losing_items = ["banana", "lipstick"]
    all_items = winning_items + losing_items
    available_items = random.sample(all_items, k=num_choices)
    print("You see these items on the table:")
    for item in available_items:
        print(f" - {item}")
    print("Which item will you choose?")
    
    command = True
    
#adding a condition (.lower allows the user to use any case they'd like.)
    while(command): #Adding a loop to execute the statement if command is true or false
        
        user_input = input(prompt = "Choose an item from the list above.") #Getting the user input

        if user_input.lower() in winning_items:
            command=False
            stage3_trinity()
#continuing the condition statement  
        elif user_input.lower() in losing_items:
            print(f"Why would you choose {user_input}? That's weird...")
            lose()
        else:
            print(f"Sorry, there is no {user_input} to pick up.")
    

#########################################################
############### Time to save Trinity... ################
#########################################################

#named stage3_trinity
def stage3_trinity():
    """Get the fighting cause from the player.
    """
    print("You're going to save Trinity- Leo's grilfriend.\n Are you care about climate change or only care about money? \n When you are looking for a job or creating a business.\n Which one do you choose?\n")    
    
    command = True
    while(command):  #Adding a loop to execute the statement if command is true or false
        
        user_input = input(prompt = 'Please answer by writing "climate change" or "money", then hit enter.\n')#Getting the user input
        
#adding a condition (.lower allows the user to use any case they'd like.)
        if user_input.lower() == 'money':
            print('''
            
            
            
 .-----------------. .----------------.  .----------------. 
| .--------------. || .--------------. || .--------------. |
| | ____  _____  | || |     ____     | || |              | |
| ||_   \|_   _| | || |   .'    `.   | || |      _       | |
| |  |   \ | |   | || |  /  .--.  \  | || |     | |      | |
| |  | |\ \| |   | || |  | |    | |  | || |     | |      | |
| | _| |_\   |_  | || |  \  `--'  /  | || |     | |      | |
| ||_____|\____| | || |   `.____.'   | || |     |_|      | |
| |              | || |              | || |     (_)      | |
| '--------------' || '--------------' || '--------------' |
 '----------------'  '----------------'  '----------------' 

            
The world has enough talents only care about money...We don't need one more!''')
            command = False
            lose()
            
#continuing the condition statment       
        elif user_input.lower() == 'climate change':
            print(''' 
            
            
                                                                       
                                       ,,                              
`7MMF'     A     `7MF'               `7MM                           OO 
  `MA     ,MA     ,V                   MM                           88 
   VM:   ,VVM:   ,V ,pW"Wq.   ,pW"Wq.  MMpMMMb.  ,pW"Wq.   ,pW"Wq.  || 
    MM.  M' MM.  M'6W'   `Wb 6W'   `Wb MM    MM 6W'   `Wb 6W'   `Wb || 
    `MM A'  `MM A' 8M     M8 8M     M8 MM    MM 8M     M8 8M     M8 `' 
     :MM;    :MM;  YA.   ,A9 YA.   ,A9 MM    MM YA.   ,A9 YA.   ,A9 ,, 
      VF      VF    `Ybmd9'   `Ybmd9'.JMML  JMML.`Ybmd9'   `Ybmd9'  db 
                                                                       
                                                                       

            
You are the one we are looking for! Yes, you are my Leo!!! You can save Trinity!!!\n''')
            command = False
            win()
            
#ending the condition                               
        else: command = True    

# win function
def win():
    """Show the player the winning screen.
    """
    print('''
    
    
   ____     __   ,-----.      ___    _         .--.      .--..-./`) ,---.   .--. 
   \   \   /  /.'  .-,  '.  .'   |  | |        |  |_     |  |\ .-.')|    \  |  | 
    \  _. /  '/ ,-.|  \ _ \ |   .'  | |        | _( )_   |  |/ `-' \|  ,  \ |  | 
     _( )_ .';  \  '_ /  | :.'  '_  | |        |(_ o _)  |  | `-'`"`|  |\_ \|  | 
 ___(_ o _)' |  _`,/ \ _/  |'   ( \.-.|        | (_,_) \ |  | .---. |  _( )_\  | 
|   |(_,_)'  : (  '\_/ \   ;' (`. _` /|        |  |/    \|  | |   | | (_ o _)  | 
|   `-'  /    \ `"/  \  ) / | (_ (_) _)        |  '  /\  `  | |   | |  (_,_)\  | 
 \      /      '. \_/``".'   \ /  . \ /        |    /  \    | |   | |  |    |  | 
  `-..-'         '-----'      ``-'`-''         `---'    `---` '---' '--'    '--' 
                                                                                 

    
You saved Trinity!!!''')

#results in a "fail"
def lose():    
    """Show the player the losing screen.
    """
    print('''
    
    
▓██   ██▓ ▒█████   █    ██     ██▓     ▒█████    ██████ ▓█████    
 ▒██  ██▒▒██▒  ██▒ ██  ▓██▒   ▓██▒    ▒██▒  ██▒▒██    ▒ ▓█   ▀    
  ▒██ ██░▒██░  ██▒▓██  ▒██░   ▒██░    ▒██░  ██▒░ ▓██▄   ▒███      
  ░ ▐██▓░▒██   ██░▓▓█  ░██░   ▒██░    ▒██   ██░  ▒   ██▒▒▓█  ▄    
  ░ ██▒▓░░ ████▓▒░▒▒█████▓    ░██████▒░ ████▓▒░▒██████▒▒░▒████▒   
   ██▒▒▒ ░ ▒░▒░▒░ ░▒▓▒ ▒ ▒    ░ ▒░▓  ░░ ▒░▒░▒░ ▒ ▒▓▒ ▒ ░░░ ▒░ ░   
 ▓██ ░▒░   ░ ▒ ▒░ ░░▒░ ░ ░    ░ ░ ▒  ░  ░ ▒ ▒░ ░ ░▒  ░ ░ ░ ░  ░   
 ▒ ▒ ░░  ░ ░ ░ ▒   ░░░ ░ ░      ░ ░   ░ ░ ░ ▒  ░  ░  ░     ░      
 ░ ░         ░ ░     ░            ░  ░    ░ ░        ░     ░  ░   
 ░ ░                                                              

    
Sorry! You lose... ''')

#calling the stage1_choice function    
stage1_choice()
# Out:
#
#
#
#
#
# ████████╗██╗  ██╗███████╗    ███╗   ███╗ █████╗ ████████╗██████╗ ██╗██╗  ██╗
# ╚══██╔══╝██║  ██║██╔════╝    ████╗ ████║██╔══██╗╚══██╔══╝██╔══██╗██║╚██╗██╔╝
#    ██║   ███████║█████╗      ██╔████╔██║███████║   ██║   ██████╔╝██║ ╚███╔╝
#    ██║   ██╔══██║██╔══╝      ██║╚██╔╝██║██╔══██║   ██║   ██╔══██╗██║ ██╔██╗
#    ██║   ██║  ██║███████╗    ██║ ╚═╝ ██║██║  ██║   ██║   ██║  ██║██║██╔╝ ██╗
#    ╚═╝   ╚═╝  ╚═╝╚══════╝    ╚═╝     ╚═╝╚═╝  ╚═╝   ╚═╝   ╚═╝  ╚═╝╚═╝╚═╝  ╚═╝
#
#
#                                                                       .         .
#
# Welcome to The New Matrix text adventure game by Amber Wang! ❤️
# Have you watched the movie - The Matrix?
#
# Are you satisfied with the new Matrix 4- The Matrix Resurrections?
# If yes, what would you like to rewrite The Matrix Resurrections?
#
# There are 3 stages in this game which Leo must go through in order to bring Trinity back home:
#
#         Stage1) Choose the right pill: Red pill or blue pill
# ...
